# %% [markdown]
# ### BCC Signature

# %%
import numpy as np
import pandas as pd

# %%
#### BCC_ALL_MUTATIONS.tsv is a big file, in order to save memory, only few columns are extracted as follow: 
#### awk -F'\t' 'BEGIN { OFS = "\t"; ORS = "\n" } {print $1,$5,$6,$7,$8,$9,$10,$18,$19,$21,$54,$55}' BCC_filtered_ALL_MUTATIONS.txt > BCC_ALL_MUTATIONS.jx.tsv

# load BCC data file
muts_df = pd.read_csv("BCC_ALL_MUTATIONS.jx.tsv", sep='\t',header=0)

# %%
muts_df.head()
# Out:
#   Hugo_Symbol Chromosome  Start_position  End_position Transcript_Strand
# 0        DNM3          1       172100820     172100820                 +  \
# 1         KMO          1       241712290     241712290                 +
# 2        DTNB          2        25602424      25602424                 -
# 3      FAHD2A          2        96079744      96079744                 +
# 4      KANSL3          2        97267966      97267966                 -
#
#   Variant_Classification Variant_Type cDNA_Change Protein_Change
# 0                 Intron          SNP         NaN            NaN  \
# 1                 Intron          SNP         NaN            NaN
# 2                 Intron          SNP         NaN            NaN
# 3                  3'UTR          SNP         NaN            NaN
# 4      Missense_Mutation          SNP   c.2369G>A        p.G790D
#
#              ref_context context signature_context
# 0  TATTGATGCACAGTTAATAAA     ACA           ACA_C>T
# 1  cttgaggccgggagtttgaga     CCC           CCC_C>T
# 2  TCAGGAGAAGGAAAGTCATTA     TCC           TCC_C>T
# 3  CACTGATGGCAAGCTTTGGGT     TTG           TTG_T>A
# 4  AGGAGTGGCACCCAAGGAGGA     ACC           ACC_C>T

# %%
#### cases without signature context
set(muts_df[muts_df['signature_context'] == '-']["Variant_Type"])
# Out:
# {'DEL', 'DNP', 'INS', 'TNP'}

# %%
#### drop the cases without signature context
muts_df = muts_df[muts_df['signature_context'] != '-']

# %%
#### Types of variant
#### PROBLEM: There is No synonymous mutation
set(muts_df["Variant_Classification"])
# Out:
# {"3'UTR",
#  "5'Flank",
#  "5'UTR",
#  'De_novo_Start_InFrame',
#  'De_novo_Start_OutOfFrame',
#  'IGR',
#  'Intron',
#  'Missense_Mutation',
#  'Nonsense_Mutation',
#  'Nonstop_Mutation',
#  'RNA',
#  'Silent',
#  'Splice_Site',
#  'Start_Codon_SNP',
#  'lincRNA'}

# %%
muts_df[muts_df.Variant_Classification == 'Silent'].head()
# Out:
#    Hugo_Symbol Chromosome  Start_position  End_position Transcript_Strand
# 8          TTN          2       179615901     179615901                 -  \
# 16      ERGIC1          5       172377723     172377723                 +
# 26     OR56B3P         11         6149942       6149942                 +
# 59       ISG15          1          949555        949555                 +
# 60        AGRN          1          982211        982211                 +
#
#    Variant_Classification Variant_Type cDNA_Change Protein_Change
# 8                  Silent          SNP  c.11226G>A       p.L3742L  \
# 16                 Silent          SNP    c.777C>T        p.I259I
# 26                 Silent          SNP    c.103C>T         p.L35L
# 59                 Silent          SNP    c.195G>A         p.L65L
# 60                 Silent          SNP   c.3262T>C       p.L1088L
#
#               ref_context context signature_context
# 8   CTCTAGAGAACAGAATATCTT     ACA           ACA_C>T
# 16  TCTGTGCCATCATTGGCGGGA     TCA           TCA_C>T
# 26  CTGGCTCTCCCTGCCCTTAGC     CCT           CCT_C>T
# 59  GCCAGGGCCTGGGCCCCGGCA     CCA           CCA_C>T
# 60  GCTCGAGCCCTTGGAGGGCAG     CTT           CTT_T>C

# %%
#### keep only missense, nonsense, nonstop, splice site
#### There is no synonymous mutation
muts_df = muts_df[muts_df.Variant_Classification.map(lambda x: x in ['Missense_Mutation', 
                                                                     'Nonsense_Mutation', 
                                                                     'Nonstop_Mutation', 
                                                                     'Splice_Site', 
                                                                     'Start_Codon_SNP', 
                                                                     'Silent'])]

# %%
#### BCC signature
#### only for all the mutations in the target
muts_gb = muts_df.groupby(['signature_context'])
muts_sign_sizes = muts_gb.size()
signature = muts_sign_sizes/sum(muts_sign_sizes)
print(signature)
# Out:
# signature_context
# ACA_C>A    0.002372
# ACA_C>G    0.000685
# ACA_C>T    0.002413
# ACC_C>A    0.001187
# ACC_C>G    0.000593
#              ...
# TTG_T>C    0.002784
# TTG_T>G    0.001036
# TTT_T>A    0.003460
# TTT_T>C    0.002939
# TTT_T>G    0.001409
# Length: 96, dtype: float64

# %%
#### save BCC signature to csv
signature.to_csv("BCC_signature.tsv", sep="\t", header=None)

# %% [markdown]
# ### BCC background

# %%
## extract penta-nucleotide
penta      = muts_df.ref_context.map(lambda x : x[8:13])

## if lower case then return Reverse Complement 
penta      = penta.map(lambda x : x if x.isupper() else x.replace("t", "A").replace("g", "C").replace("a", "T").replace("c", "G")[::-1])

## left adjacent context and right adjacent context
la_context = penta.map(lambda x : x[:3])
ra_context = penta.map(lambda x : x[2:])

muts_df["penta_context"]          = penta
muts_df["left_adjacent_context"]  = la_context
muts_df["right_adjacent_context"] = ra_context
muts_df.head()
# Out:
#    Hugo_Symbol Chromosome  Start_position  End_position Transcript_Strand
# 4       KANSL3          2        97267966      97267966                 -  \
# 5      ANKRD36          2        97827852      97827852                 +
# 7        SCN7A          2       167300176     167300176                 -
# 8          TTN          2       179615901     179615901                 -
# 11       UNC80          2       210761082     210761082                 +
#
#    Variant_Classification Variant_Type cDNA_Change Protein_Change
# 4       Missense_Mutation          SNP   c.2369G>A        p.G790D  \
# 5       Missense_Mutation          SNP   c.1406C>T        p.P469L
# 7       Missense_Mutation          SNP   c.1637G>A        p.G546E
# 8                  Silent          SNP  c.11226G>A       p.L3742L
# 11      Missense_Mutation          SNP   c.4313G>A       p.G1438E
#
#               ref_context context signature_context penta_context
# 4   AGGAGTGGCACCCAAGGAGGA     ACC           ACC_C>T         CACCC  \
# 5   AAAGCACTACCAGCAACTGGA     CCA           CCA_C>T         ACCAG
# 7   TGTGAAAATTCCAATGAAAAC     TCC           TCC_C>T         TTCCA
# 8   CTCTAGAGAACAGAATATCTT     ACA           ACA_C>T         AACAG
# 11  GAGCCAGAGGGAATGAGTAAT     TCC           TCC_C>T         GGGAA
#
#    left_adjacent_context right_adjacent_context
# 4                    CAC                    CCC
# 5                    ACC                    CAG
# 7                    TTC                    CCA
# 8                    AAC                    CAG
# 11                   GGG                    GAA

# %%
## types of mutation
muts_df["mutation"] = muts_df.signature_context.map(lambda x: x.split('_')[1])
muts_df["mut_nul"]  = muts_df.mutation.map(lambda x: x.split('>')[1])
muts_df.head()
# Out:
#    Hugo_Symbol Chromosome  Start_position  End_position Transcript_Strand
# 4       KANSL3          2        97267966      97267966                 -  \
# 5      ANKRD36          2        97827852      97827852                 +
# 7        SCN7A          2       167300176     167300176                 -
# 8          TTN          2       179615901     179615901                 -
# 11       UNC80          2       210761082     210761082                 +
#
#    Variant_Classification Variant_Type cDNA_Change Protein_Change
# 4       Missense_Mutation          SNP   c.2369G>A        p.G790D  \
# 5       Missense_Mutation          SNP   c.1406C>T        p.P469L
# 7       Missense_Mutation          SNP   c.1637G>A        p.G546E
# 8                  Silent          SNP  c.11226G>A       p.L3742L
# 11      Missense_Mutation          SNP   c.4313G>A       p.G1438E
#
#               ref_context context signature_context penta_context
# 4   AGGAGTGGCACCCAAGGAGGA     ACC           ACC_C>T         CACCC  \
# 5   AAAGCACTACCAGCAACTGGA     CCA           CCA_C>T         ACCAG
# 7   TGTGAAAATTCCAATGAAAAC     TCC           TCC_C>T         TTCCA
# 8   CTCTAGAGAACAGAATATCTT     ACA           ACA_C>T         AACAG
# 11  GAGCCAGAGGGAATGAGTAAT     TCC           TCC_C>T         GGGAA
#
#    left_adjacent_context right_adjacent_context mutation mut_nul
# 4                    CAC                    CCC      C>T       T
# 5                    ACC                    CAG      C>T       T
# 7                    TTC                    CCA      C>T       T
# 8                    AAC                    CAG      C>T       T
# 11                   GGG                    GAA      C>T       T

# %%
muts_df["signature_penta_context"] = muts_df[["penta_context", "mutation"]].aggregate('_'.join, axis=1)

muts_df.head()
# Out:
#    Hugo_Symbol Chromosome  Start_position  End_position Transcript_Strand
# 4       KANSL3          2        97267966      97267966                 -  \
# 5      ANKRD36          2        97827852      97827852                 +
# 7        SCN7A          2       167300176     167300176                 -
# 8          TTN          2       179615901     179615901                 -
# 11       UNC80          2       210761082     210761082                 +
#
#    Variant_Classification Variant_Type cDNA_Change Protein_Change
# 4       Missense_Mutation          SNP   c.2369G>A        p.G790D  \
# 5       Missense_Mutation          SNP   c.1406C>T        p.P469L
# 7       Missense_Mutation          SNP   c.1637G>A        p.G546E
# 8                  Silent          SNP  c.11226G>A       p.L3742L
# 11      Missense_Mutation          SNP   c.4313G>A       p.G1438E
#
#               ref_context context signature_context penta_context
# 4   AGGAGTGGCACCCAAGGAGGA     ACC           ACC_C>T         CACCC  \
# 5   AAAGCACTACCAGCAACTGGA     CCA           CCA_C>T         ACCAG
# 7   TGTGAAAATTCCAATGAAAAC     TCC           TCC_C>T         TTCCA
# 8   CTCTAGAGAACAGAATATCTT     ACA           ACA_C>T         AACAG
# 11  GAGCCAGAGGGAATGAGTAAT     TCC           TCC_C>T         GGGAA
#
#    left_adjacent_context right_adjacent_context mutation mut_nul
# 4                    CAC                    CCC      C>T       T  \
# 5                    ACC                    CAG      C>T       T
# 7                    TTC                    CCA      C>T       T
# 8                    AAC                    CAG      C>T       T
# 11                   GGG                    GAA      C>T       T
#
#    signature_penta_context
# 4                CACCC_C>T
# 5                ACCAG_C>T
# 7                TTCCA_C>T
# 8                AACAG_C>T
# 11               GGGAA_C>T

# %%
STOP      = "STOP"

MISSENSE  = "Missense_Mutation" # "missense"
NONSENSE  = "Nonsense_Mutation" # "nonsense"
SYNONYMOUS= "Silent" # "coding-synon"

cDNA_genetic_code = {"G": 
                        {"G": {"G": "Gly", "A": "Gly", "C": "Gly", "T": "Gly"},
                         "A": {"G": "Glu", "A": "Glu", "C": "Asp", "T": "Asp"},
                         "C": {"G": "Ala", "A": "Ala", "C": "Ala", "T": "Ala"},
                         "T": {"G": "Val", "A": "Val", "C": "Val", "T": "Val"}},
                     "A": 
                        {"G": {"G": "Arg", "A": "Arg", "C": "Ser", "T": "Ser"},
                         "A": {"G": "Lys", "A": "Lys", "C": "Asn", "T": "Asn"},
                         "C": {"G": "Thr", "A": "Thr", "C": "Thr", "T": "Thr"},
                         "T": {"G": "Met", "A": "Ile", "C": "Ile", "T": "Ile"}},
                     "C": 
                        {"G": {"G": "Arg", "A": "Arg", "C": "Arg", "T": "Arg"},
                         "A": {"G": "Gln", "A": "Gln", "C": "His", "T": "His"},
                         "C": {"G": "Pro", "A": "Pro", "C": "Pro", "T": "Pro"},
                         "T": {"G": "Leu", "A": "Leu", "C": "Leu", "T": "Leu"}},
                     "T": 
                        {"G": {"G": "Trp", "A":  STOP, "C": "Cys", "T": "Cys"},
                         "A": {"G":  STOP, "A":  STOP, "C": "Tyr", "T": "Tyr"},
                         "C": {"G": "Ser", "A": "Ser", "C": "Ser", "T": "Ser"},
                         "T": {"G": "Leu", "A": "Leu", "C": "Phe", "T": "Phe"}}}

def func_mut_type(ref_cnt: str, mut_cnt: str):
    if cDNA_genetic_code[ref_cnt[0]][ref_cnt[1]][ref_cnt[2]] != STOP and cDNA_genetic_code[mut_cnt[0]][mut_cnt[1]][mut_cnt[2]] == STOP: 
        return NONSENSE
    elif cDNA_genetic_code[ref_cnt[0]][ref_cnt[1]][ref_cnt[2]] != cDNA_genetic_code[mut_cnt[0]][mut_cnt[1]][mut_cnt[2]]:
        return MISSENSE
    elif cDNA_genetic_code[ref_cnt[0]][ref_cnt[1]][ref_cnt[2]] == cDNA_genetic_code[mut_cnt[0]][mut_cnt[1]][mut_cnt[2]]: 
        return SYNONYMOUS
   
#### reverse complement 
def rc(x):
    return x.lower().replace("t", "A").replace("g", "C").replace("a", "T").replace("c", "G")[::-1]

# %%
la_mut_type = muts_df.signature_penta_context.map(lambda x : func_mut_type(x[0:3], x[0:2] + x[-1]))
sg_mut_type = muts_df.signature_penta_context.map(lambda x : func_mut_type(x[1:4], x[1] + x[-1] + x[3]))
ra_mut_type = muts_df.signature_penta_context.map(lambda x : func_mut_type(x[2:5], x[-1] + x[3:5]))

#### reverse complement
la_rc_mut_type = muts_df.signature_penta_context.map(lambda x : func_mut_type(rc(x[0:3]), rc(x[0:2] + x[-1])))
sg_rc_mut_type = muts_df.signature_penta_context.map(lambda x : func_mut_type(rc(x[1:4]), rc(x[1]   + x[-1] + x[3])))
ra_rc_mut_type = muts_df.signature_penta_context.map(lambda x : func_mut_type(rc(x[2:5]), rc(x[-1]  + x[3:5])))

muts_df["left_adjacent_mut_type"] = la_mut_type
muts_df["signautre_mut_type"]     = sg_mut_type
muts_df["right_adjacent_mut_type"]= ra_mut_type

#### reverse complement
muts_df["left_adjacent_rc_mut_type"] = la_rc_mut_type
muts_df["signautre_rc_mut_type"]     = sg_rc_mut_type
muts_df["right_adjacent_rc_mut_type"]= ra_rc_mut_type

muts_df.head()
# Out:
#    Hugo_Symbol Chromosome  Start_position  End_position Transcript_Strand
# 4       KANSL3          2        97267966      97267966                 -  \
# 5      ANKRD36          2        97827852      97827852                 +
# 7        SCN7A          2       167300176     167300176                 -
# 8          TTN          2       179615901     179615901                 -
# 11       UNC80          2       210761082     210761082                 +
#
#    Variant_Classification Variant_Type cDNA_Change Protein_Change
# 4       Missense_Mutation          SNP   c.2369G>A        p.G790D  \
# 5       Missense_Mutation          SNP   c.1406C>T        p.P469L
# 7       Missense_Mutation          SNP   c.1637G>A        p.G546E
# 8                  Silent          SNP  c.11226G>A       p.L3742L
# 11      Missense_Mutation          SNP   c.4313G>A       p.G1438E
#
#               ref_context  ... right_adjacent_context mutation mut_nul
# 4   AGGAGTGGCACCCAAGGAGGA  ...                    CCC      C>T       T  \
# 5   AAAGCACTACCAGCAACTGGA  ...                    CAG      C>T       T
# 7   TGTGAAAATTCCAATGAAAAC  ...                    CCA      C>T       T
# 8   CTCTAGAGAACAGAATATCTT  ...                    CAG      C>T       T
# 11  GAGCCAGAGGGAATGAGTAAT  ...                    GAA      C>T       T
#
#    signature_penta_context left_adjacent_mut_type signautre_mut_type
# 4                CACCC_C>T                 Silent  Missense_Mutation  \
# 5                ACCAG_C>T                 Silent  Missense_Mutation
# 7                TTCCA_C>T                 Silent  Missense_Mutation
# 8                AACAG_C>T                 Silent  Missense_Mutation
# 11               GGGAA_C>T                 Silent  Missense_Mutation
#
#    right_adjacent_mut_type left_adjacent_rc_mut_type signautre_rc_mut_type
# 4        Missense_Mutation         Missense_Mutation     Missense_Mutation  \
# 5        Nonsense_Mutation         Missense_Mutation     Nonsense_Mutation
# 7        Missense_Mutation         Missense_Mutation     Missense_Mutation
# 8        Nonsense_Mutation         Missense_Mutation     Missense_Mutation
# 11       Nonsense_Mutation         Missense_Mutation     Missense_Mutation
#
#    right_adjacent_rc_mut_type
# 4                      Silent
# 5                      Silent
# 7           Nonsense_Mutation
# 8                      Silent
# 11          Missense_Mutation
#
# [5 rows x 24 columns]

# %%
muts_df[muts_df.Variant_Classification != muts_df.signautre_mut_type].head()
# Out:
#    Hugo_Symbol Chromosome  Start_position  End_position Transcript_Strand
# 8          TTN          2       179615901     179615901                 -  \
# 14    EPM2AIP1          3        37033404      37033404                 -
# 16      ERGIC1          5       172377723     172377723                 +
# 26     OR56B3P         11         6149942       6149942                 +
# 59       ISG15          1          949555        949555                 +
#
#    Variant_Classification Variant_Type cDNA_Change Protein_Change
# 8                  Silent          SNP  c.11226G>A       p.L3742L  \
# 14      Nonsense_Mutation          SNP   c.1165G>T        p.E389*
# 16                 Silent          SNP    c.777C>T        p.I259I
# 26                 Silent          SNP    c.103C>T         p.L35L
# 59                 Silent          SNP    c.195G>A         p.L65L
#
#               ref_context  ... right_adjacent_context mutation mut_nul
# 8   CTCTAGAGAACAGAATATCTT  ...                    CAG      C>T       T  \
# 14  CGAAGGTGTTCCATAATGTCC  ...                    CCA      C>A       A
# 16  TCTGTGCCATCATTGGCGGGA  ...                    CAT      C>T       T
# 26  CTGGCTCTCCCTGCCCTTAGC  ...                    CTG      C>T       T
# 59  GCCAGGGCCTGGGCCCCGGCA  ...                    GGG      C>T       T
#
#    signature_penta_context left_adjacent_mut_type signautre_mut_type
# 8                AACAG_C>T                 Silent  Missense_Mutation  \
# 14               TTCCA_C>A      Missense_Mutation  Missense_Mutation
# 16               ATCAT_C>T                 Silent  Missense_Mutation
# 26               CCCTG_C>T                 Silent  Missense_Mutation
# 59               CTGGG_C>T                 Silent  Missense_Mutation
#
#    right_adjacent_mut_type left_adjacent_rc_mut_type signautre_rc_mut_type
# 8        Nonsense_Mutation         Missense_Mutation     Missense_Mutation  \
# 14       Missense_Mutation         Nonsense_Mutation     Missense_Mutation
# 16       Missense_Mutation         Missense_Mutation                Silent
# 26                  Silent         Missense_Mutation     Missense_Mutation
# 59       Missense_Mutation         Missense_Mutation     Missense_Mutation
#
#    right_adjacent_rc_mut_type
# 8                      Silent
# 14          Missense_Mutation
# 16          Missense_Mutation
# 26                     Silent
# 59                     Silent
#
# [5 rows x 24 columns]

# %%
muts_df_head = muts_df.head(1000)

## Drop splice sites for this comparasion
muts_df_head = muts_df_head[muts_df_head.Variant_Classification.map(lambda x: x != 'Splice_Site')]

## Question: some Variant Classification correspond to none of the mutation type of the following 6 contexts
problem_set = muts_df_head[muts_df_head.apply(func = lambda x: x.Variant_Classification not in [x.left_adjacent_mut_type, 
                                                                                  x.signautre_mut_type, 
                                                                                  x.right_adjacent_mut_type, 
                                                                                  x.left_adjacent_rc_mut_type, 
                                                                                  x.signautre_rc_mut_type, 
                                                                                  x.right_adjacent_rc_mut_type], 
                                axis = 1)]

# [["context","signature_context","penta_context","left_adjacent_context","right_adjacent_context"]]
# problem_set

# %%
## join BCC signature
muts_df = muts_df.set_index("signature_context").join(pd.DataFrame(signature, columns=["BCC_signature"]), how="outer").reset_index()

# %%
genes_gb = muts_df.groupby(["Hugo_Symbol"])
gene_EPM2AIP1 = genes_gb.get_group("EPM2AIP1")
gene_EPM2AIP1
# Out:
#        signature_context Hugo_Symbol Chromosome  Start_position  End_position
# 88803            CCA_C>T    EPM2AIP1          3        37033751      37033751  \
# 295373           CTG_T>G    EPM2AIP1          3        37033462      37033462
# 295494           CTG_T>G    EPM2AIP1          3        37033462      37033462
# 369277           TCA_C>T    EPM2AIP1          3        37033258      37033258
# 380142           TCA_C>T    EPM2AIP1          3        37033478      37033478
# 391038           TCA_C>T    EPM2AIP1          3        37033819      37033819
# 406384           TCC_C>A    EPM2AIP1          3        37033404      37033404
# 559055           TCC_C>T    EPM2AIP1          3        37033200      37033200
# 645001           TCT_C>T    EPM2AIP1          3        37033944      37033944
# 664135           TCT_C>T    EPM2AIP1          3        37032768      37032768
# 698196           TTA_T>C    EPM2AIP1          3        37033526      37033526
#
#        Transcript_Strand Variant_Classification Variant_Type cDNA_Change
# 88803                  -      Nonsense_Mutation          SNP    c.818G>A  \
# 295373                 -                 Silent          SNP   c.1107A>C
# 295494                 -                 Silent          SNP   c.1107A>C
# 369277                 -                 Silent          SNP   c.1311C>T
# 380142                 -      Missense_Mutation          SNP   c.1091C>T
# 391038                 -                 Silent          SNP    c.750G>A
# 406384                 -      Nonsense_Mutation          SNP   c.1165G>T
# 559055                 -      Missense_Mutation          SNP   c.1369C>T
# 645001                 -                 Silent          SNP    c.625C>T
# 664135                 -      Missense_Mutation          SNP   c.1801G>A
# 698196                 -      Missense_Mutation          SNP   c.1043T>C
#
#        Protein_Change  ... mutation mut_nul signature_penta_context
# 88803         p.W273*  ...      C>T       T               TCCAA_C>T  \
# 295373        p.T369T  ...      T>G       G               ACTGT_T>G
# 295494        p.T369T  ...      T>G       G               ACTGT_T>G
# 369277        p.L437L  ...      C>T       T               CTGAG_C>T
# 380142        p.S364L  ...      C>T       T               CTGAA_C>T
# 391038        p.L250L  ...      C>T       T               CTCAA_C>T
# 406384        p.E389*  ...      C>A       A               TTCCA_C>A
# 559055        p.P457S  ...      C>T       T               AGGAT_C>T
# 645001        p.L209L  ...      C>T       T               CAGAA_C>T
# 664135        p.E601K  ...      C>T       T               TTCTC_C>T
# 698196        p.L348S  ...      T>C       C               TTAAA_T>C
#
#        left_adjacent_mut_type signautre_mut_type right_adjacent_mut_type
# 88803                  Silent  Missense_Mutation       Nonsense_Mutation  \
# 295373                 Silent  Missense_Mutation       Missense_Mutation
# 295494                 Silent  Missense_Mutation       Missense_Mutation
# 369277                 Silent  Missense_Mutation       Nonsense_Mutation
# 380142                 Silent  Missense_Mutation       Nonsense_Mutation
# 391038                 Silent  Missense_Mutation       Nonsense_Mutation
# 406384      Missense_Mutation  Missense_Mutation       Missense_Mutation
# 559055      Missense_Mutation  Missense_Mutation       Missense_Mutation
# 645001      Missense_Mutation  Missense_Mutation       Nonsense_Mutation
# 664135                 Silent  Missense_Mutation       Missense_Mutation
# 698196      Missense_Mutation  Missense_Mutation       Missense_Mutation
#
#        left_adjacent_rc_mut_type signautre_rc_mut_type
# 88803          Missense_Mutation     Nonsense_Mutation  \
# 295373         Missense_Mutation     Missense_Mutation
# 295494         Missense_Mutation     Missense_Mutation
# 369277         Missense_Mutation     Nonsense_Mutation
# 380142         Missense_Mutation     Nonsense_Mutation
# 391038         Missense_Mutation                Silent
# 406384         Nonsense_Mutation     Missense_Mutation
# 559055         Missense_Mutation     Missense_Mutation
# 645001         Missense_Mutation     Missense_Mutation
# 664135         Missense_Mutation     Missense_Mutation
# 698196         Missense_Mutation     Nonsense_Mutation
#
#        right_adjacent_rc_mut_type BCC_signature
# 88803                      Silent      0.065905
# 295373                     Silent      0.001832
# 295494                     Silent      0.001832
# 369277                     Silent      0.068510
# 380142          Missense_Mutation      0.068510
# 391038                     Silent      0.068510
# 406384          Missense_Mutation      0.003176
# 559055                     Silent      0.228051
# 645001          Missense_Mutation      0.079674
# 664135                     Silent      0.079674
# 698196          Missense_Mutation      0.002009
#
# [11 rows x 25 columns]

# %%
muts_gb = gene_EPM2AIP1.groupby(["Variant_Classification"])

synonymous = muts_gb.get_group(SYNONYMOUS)
nonsense   = muts_gb.get_group(NONSENSE)
missense   = muts_gb.get_group(MISSENSE)

prob_subst_BCC = np.array([sum(synonymous.BCC_signature), sum(nonsense.BCC_signature), sum(missense.BCC_signature)])
fraction_subst_BCC = prob_subst_BCC / sum(prob_subst_BCC)

# %%
pd.DataFrame(np.array([prob_subst_BCC, fraction_subst_BCC]), columns=[SYNONYMOUS, NONSENSE, MISSENSE], index=["prob_subst_BCC", "fraction_subst_BCC"])
# Out:
#                       Silent  Nonsense_Mutation  Missense_Mutation
# prob_subst_BCC      0.220358           0.069081           0.378244
# fraction_subst_BCC  0.330034           0.103464           0.566503
